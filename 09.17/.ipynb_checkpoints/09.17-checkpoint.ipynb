# %% [markdown]
# ### Tuesday, September 17, 2024
#
# Today: LIF models
#
# Thursday: read HH papers
# - chapter 2
#
# Homework due 09/24
#
# ___
#
# Let C = 1

# %%
import numpy as np
import matplotlib.pyplot as plt

C=1
I=1
dt=0.01 
Vth=3
Vreset=1
V = np.zeros([1000,1])
V[0]=0  

for i in range(0,999):
    V[i+1] = V[i] + dt*(I/C)
    if V[i+1]>Vth:  # if V is too large, then reset
        V[i+1]=Vreset

# print(firing_rate)

t = np.arange(0, len(V))*dt

# Plot voltages
plt.figure()
plt.plot(t,V)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

C=3
I=1
dt=0.01 
Vth=3
Vreset=1
V = np.zeros([1000,1])
V[0]=0  

for i in range(0,999):
    V[i+1] = V[i] + dt*(I/C)
    if V[i+1]>Vth:  # if V is too large, then reset
        V[i+1]=Vreset

t = np.arange(0, len(V))*dt

# Plot voltages
plt.figure()
plt.plot(t,V)
plt.show()

# %% [markdown]
# ## What happens if we double C?
#
# #### Why does this make sense?
#
# C = Cm * A
#
# C = total capacitance
#
# Cm= membrane capacitance
#
# A = surface area of the membrane
#
# If we double C, does this mean we increase the surface area of the membrane?
# - C = capacity for neuron to hold charge
# - Increase C ==> Increase capacity of neuron to hold more charge
# - Larger surface area = membrane can store more charge ==> slows the change in membrane potential
