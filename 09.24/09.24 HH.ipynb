# %%
import numpy as np
import matplotlib.pyplot as plt

import requests
url = "https://raw.githubusercontent.com/Mark-Kramer/BU-MA665-MA666/master/HH_functions.py"
response = requests.get(url)
exec(response.text)

I0 = 10
T0 = 100
[V,m,h,n,t]=HH(I0,T0)
plt.plot(t,V)
plt.title("Voltage vs Time")
plt.xlabel("Time (ms)")
plt.ylabel("Membrane Potential (mV)")
plt.show()

plt.plot(t,m)
plt.title("m vs Time")
plt.xlabel("Time (ms)")
plt.show()

plt.plot(t,h)
plt.title("h vs Time")
plt.xlabel("Time (ms)")
plt.show()

plt.plot(t,n)
plt.title("n vs Time")
plt.xlabel("Time (ms)")
plt.show()

# %%
plt.figure()
plt.plot(t,V,'k')
plt.xlim([35, 55])
plt.ylabel('V [mV]')
plt.show()

# %%
# m gate is opening very quickly
plt.figure()
plt.plot(t,m,'r', label='m')
plt.xlim([35, 55])
plt.show()

# %%
# what is happening here?
plt.figure()
plt.plot(t,m,'r', label='m')
plt.plot(t,h,'b', label='h')
plt.plot(t,n,'g', label='n')
plt.xlim([35, 55])
plt.xlabel('Time [ms]');
plt.legend();
plt.show()

# %%
plt.figure()
ax1 = plt.subplot(211);                 # Define axis for 1st subplot,
ax2 = plt.subplot(212, sharex=ax1);     # ... and link axis of 2nd subplot to the 1st.
ax1.plot(t,V,'k')                   # Plot the voltage in the first subplot,
plt.xlim([35, 55])
ax2.plot(t,m,'r', label='m')        # ... and the gating variables in the other subplot.
ax2.plot(t,h,'b', label='h')
ax2.plot(t,n,'g', label='n')
plt.xlabel('Time [ms]')
plt.legend()
plt.show()

# %%
# Plot conductances
gNa0 = 120
gNa  = gNa0*(m**3)*h                    #Sodium conductance
gK0  = 36
gK   = gK0*(n**4)                    #Potassium conductance
gL0  = 0.3
gL   = gL0                    #Leak conductance

plt.figure()
plt.plot(t,gNa,'m', label='gNa')#... and plot the sodium conductance,
plt.plot(t,gK, 'g', label='gK') #... and plot the potassium conductance,
plt.plot(t,gL, 'k', label='gL') #... and plot the leak conductance.
plt.xlim([35, 55])
plt.xlabel('Time [ms]')             #... label the x-axis.
plt.ylabel('mS/cm^2')               #... and label the y-axis.
plt.legend()                        #... make a legend.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 12
#      10 plt.plot(t,gNa,'m', label='gNa')#... and plot the sodium conductance,
#      11 plt.plot(t,gK, 'g', label='gK') #... and plot the potassium conductance,
# ---> 12 plt.plot(t,gL, 'k', label='gL') #... and plot the leak conductance.
#      13 plt.xlim([35, 55])
#      14 plt.xlabel('Time [ms]')             #... label the x-axis.
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
#    1482 Plot y versus x as lines and/or markers.
#    1483
#    (...)
#    1721 (``'green'``) or hex strings (``'#008000'``).
#    1722 """
#    1723 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1724 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1725 for line in lines:
#    1726     self.add_line(line)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (10000,) and (1,)

# %%
gNa0 = 120
ENa  = 115
INa  = gNa0*(m**3)*(h)*(ENa-V)  # Sodium current.
gK0  = 36
EK   =-12
IK   = ??? Potassium current.
gL0  = 0.3
EL   = 10.6;
IL   = ??? Leak current.

plt.figure()
plt.plot(t,INa,'m', label='INa')   #... and plot the sodium current,
plt.plot(t,IK, 'g', label='IK')    #... and plot the potassium current,
plt.plot(t,IL, 'k', label='IL')    #... and plot the leak current.
plt.xlim([35, 55])
plt.xlabel('Time [ms]')            #... label the x-axis.
plt.ylabel('mA/cm^2')              #... and label the y-axis.
plt.legend()                      #... make a legend.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 13
#      11 plt.figure()
#      12 plt.plot(t,INa,'m', label='INa')   #... and plot the sodium current,
# ---> 13 plt.plot(t,IK, 'g', label='IK')    #... and plot the potassium current,
#      14 plt.plot(t,IL, 'k', label='IL')    #... and plot the leak current.
#      15 plt.xlim([35, 55])
#
# NameError: name 'IK' is not defined

# %% [markdown]
# Challenges
# https://mark-kramer.github.io/BU-MA665-MA666/HH.html
#
#
# firing rate is firing per second!!! (convert ms to seconds)
# - we are only interested in persistent firing (not transient firing)
# - ignore initial transient firing (firing rate is zero if only 1 spike at the beginning but doesn't spike continually)
#
# can use built-in functions (ie findpeaks())
